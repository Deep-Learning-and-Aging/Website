# %%
PLOT_TYPE = {"manhattan": "GWAS_ManhattanPlot", "qq": "GWAS_QQPlot"}
DIMENSIONS = ['*instances1.5x', '*instances23', 'Abdomen', 'AbdomenLiver', 'AbdomenPancreas', 'All', 'Arterial', 'ArterialCarotids', 'ArterialPulseWaveAnalysis', 'Biochemistry', 'BiochemistryBlood', 'BiochemistryUrine', 'Brain', 'BrainCognitive', 'BrainMRI', 'Eyes', 'EyesFundus', 'EyesOCT', 'Hearing', 'Heart', 'HeartECG', 'HeartMRI', 'ImmuneSystem', 'Lungs', 'Musculoskeletal', 'MusculoskeletalFullBody', 'MusculoskeletalHips', 'MusculoskeletalKnees', 'MusculoskeletalScalars', 'MusculoskeletalSpine', 'PhysicalActivity']

DIMENSIONS_TO_REPLACE = {"*instances1.5x": "set_instances1.5x", "*instances23": "set_instances23", "ImmuneSystem": "BloodCells"}

if __name__ == "__main__":
    for plot_type in ["manhattan", "qq"]:
        for dimension in DIMENSIONS:
            print(f"page10_GWASResults/Manhattan/{PLOT_TYPE[plot_type]}_Age_{dimension}.png")
            print(f"genetics/gwas/{plot_type}/{DIMENSIONS_TO_REPLACE.get(dimension, dimension)}.png")

# %%
for plot_type in ["manhattan", "qq"]:
    for dimension in DIMENSIONS:
        print(f"page10_GWASResults/Manhattan/{PLOT_TYPE[plot_type]}_Age_{dimension}.png")
        print(f"genetics/gwas/{plot_type}/{DIMENSIONS_TO_REPLACE.get(dimension, dimension)}.png")
# Out:
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_*.png
# genetics/gwas/manhattan/set.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_*instances01.png
# genetics/gwas/manhattan/set_instances01.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_*instances1.5x.png
# genetics/gwas/manhattan/set_instances1.5x.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_*instances23.png
# genetics/gwas/manhattan/set_instances23.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_Abdomen.png
# genetics/gwas/manhattan/Abdomen.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_AbdomenLiver.png
# genetics/gwas/manhattan/AbdomenLiver.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_AbdomenPancreas.png
# genetics/gwas/manhattan/AbdomenPancreas.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_All.png
# genetics/gwas/manhattan/All.png
# page10_GWASResults/Manhattan/GWAS_ManhattanPlot_Age_Arterial.png
# genetics/gwas/manhattan/Arterial.png
# ...
