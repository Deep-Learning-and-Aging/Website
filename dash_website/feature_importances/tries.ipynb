# %%
import pandas as pd 

information_raw = pd.read_feather("../../all_data/feature_importances/videos/information.feather")

# %%
information_raw# .set_index([""])
# Out:
#            id     sex age_group   aging_rate  chronological_age  \
# 0   2897530_2  female       old  decelerated               75.0
# 1   3814357_2  female     young       normal               50.0
# 2   3868508_2    male     young  accelerated               50.0
# 3   5068364_2    male       old       normal               75.0
# 4   5807748_2    male    middle       normal               63.0
# 5   1540424_2    male       old  decelerated               75.0
# 6   3364330_2    male     young  decelerated               50.0
# 7   3342811_2  female    middle       normal               63.0
# 8   1243509_2    male    middle  accelerated               63.0
# 9   4999240_2    male       old  accelerated               75.0
# 10  5255033_2  female     young  decelerated               50.0
# 11  5321575_2  female    middle  decelerated               63.0
# 12  3877652_2  female       old       normal               75.0
# 13  5364841_2  female     young  accelerated               50.0
# ...
