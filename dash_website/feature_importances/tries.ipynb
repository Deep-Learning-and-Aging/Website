# %%
import pandas as pd 

features = pd.read_feather("../../all_data/feature_importances/scalars/Arterial_All_Scalars.feather").set_index("feature")

features.columns = pd.MultiIndex.from_tuples(
    list(map(eval, features.columns.tolist())), names=["algorithm", "observation"]
)
best_algorithm = "light_gbm"

sorted_features = features.abs().sort_values(by=[("light_gbm", "mean")], ascending=False).index
features.loc[sorted_features]
# Out:
# algorithm                                          correlation            \
# observation                                               mean       std
# feature
# Pulse wave peak to peak time                         -0.008356  0.000370
# Pulse wave Arterial Stiffness index                   0.007827  0.000800
# Systolic blood pressure                               0.056813  0.000555
# Diastolic blood pressure                             -0.009158  0.000496
# Pulse wave reflection index                          -0.002156  0.000478
# Mean carotid IMT (intima-medial thickness) at 1...    0.065055  0.000631
# Mean carotid IMT (intima-medial thickness) at 2...    0.057729  0.000588
# Position of pulse wave notch                         -0.001522  0.000595
# Mean carotid IMT (intima-medial thickness) at 2...    0.060367  0.000514
# Mean carotid IMT (intima-medial thickness) at 1...    0.066109  0.000441
# Position of the pulse wave peak                       0.023405  0.000546
# Position of the shoulder on the pulse waveform        0.017945  0.000448
# Minimum carotid IMT (intima-medial thickness) a...    0.060046  0.000562
# Maximum carotid IMT (intima-medial thickness) a...    0.054240  0.000543
# Minimum carotid IMT (intima-medial thickness) a...    0.051866  0.000512
# Maximum carotid IMT (intima-medial thickness) a...    0.060972  0.000680
# Maximum carotid IMT (intima-medial thickness) a...    0.060662  0.000441
# Minimum carotid IMT (intima-medial thickness) a...    0.054259  0.000358
# Maximum carotid IMT (intima-medial thickness) a...    0.056752  0.000598
# Sex                                                   0.015540  0.000593
# Minimum carotid IMT (intima-medial thickness) a...    0.058739  0.000665
# Absence of notch position in the pulse waveform       0.034732  0.000466
# British                                               0.013650  0.000683
# White                                                 0.013545  0.000599
# Other                                                -0.001142  0.000537
# White_Other                                          -0.004585  0.000660
# Irish                                                -0.004578  0.000476
# Black                                                -0.009406  0.000351
# Indian                                               -0.005129  0.000575
# African                                              -0.005462  0.000459
# White_and_Black_African                              -0.000842       NaN
# Prefer_not_to_answer                                  0.002061  0.000657
# nan                                                   0.000315       NaN
# Mixed                                                -0.006456  0.000443
# White_and_Black_Caribbean                            -0.004944  0.000508
# Mixed_Other                                          -0.003501  0.000485
# White_and_Asian                                      -0.002760  0.000460
# Black_Other                                          -0.002382       NaN
# Asian                                                -0.007639  0.000741
# Pakistani                                            -0.007164  0.000673
# Bangladeshi                                          -0.002416       NaN
# Asian_Other                                          -0.000562  0.000486
# Caribbean                                            -0.007415  0.000375
# Do_not_know                                          -0.000638       NaN
# Chinese                                              -0.006293  0.000484
# Other_ethnicity                                      -0.002865  0.000283
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
#
# algorithm                                          elastic_net            \
# observation                                               mean       std
# feature
# Pulse wave peak to peak time                          0.000105  0.000050
# Pulse wave Arterial Stiffness index                  -0.000452  0.000050
# Systolic blood pressure                               0.253542  0.000084
# Diastolic blood pressure                             -0.215752  0.000078
# Pulse wave reflection index                          -0.019612  0.000099
# Mean carotid IMT (intima-medial thickness) at 1...    0.040238  0.000168
# Mean carotid IMT (intima-medial thickness) at 2...    0.026575  0.000193
# Position of pulse wave notch                         -0.008171  0.000142
# Mean carotid IMT (intima-medial thickness) at 2...    0.043019  0.000322
# Mean carotid IMT (intima-medial thickness) at 1...    0.080561  0.000147
# Position of the pulse wave peak                       0.058823  0.000172
# Position of the shoulder on the pulse waveform       -0.012906  0.000154
# Minimum carotid IMT (intima-medial thickness) a...    0.000000  0.000039
# Maximum carotid IMT (intima-medial thickness) a...    0.000000  0.000050
# Minimum carotid IMT (intima-medial thickness) a...   -0.005887  0.000125
# Maximum carotid IMT (intima-medial thickness) a...    0.014373  0.000169
# Maximum carotid IMT (intima-medial thickness) a...    0.000884  0.000163
# Minimum carotid IMT (intima-medial thickness) a...   -0.004788  0.000202
# Maximum carotid IMT (intima-medial thickness) a...    0.008104  0.000195
# Sex                                                   0.040308  0.000084
# Minimum carotid IMT (intima-medial thickness) a...   -0.000000  0.000062
# Absence of notch position in the pulse waveform       0.053116  0.000063
# British                                               0.013016  0.000152
# White                                                 0.018138  0.000139
# Other                                                 0.003813  0.000089
# White_Other                                          -0.000000  0.000000
# Irish                                                -0.006667  0.000102
# Black                                                -0.018257  0.000063
# Indian                                               -0.000000  0.000077
# African                                              -0.000000  0.000035
# White_and_Black_African                               0.001110  0.000083
# Prefer_not_to_answer                                  0.008480  0.000099
# nan                                                   0.006049  0.000095
# Mixed                                                -0.000741  0.000071
# White_and_Black_Caribbean                            -0.005748  0.000072
# Mixed_Other                                          -0.000000  0.000028
# White_and_Asian                                       0.000000  0.000047
# Black_Other                                          -0.001810  0.000022
# Asian                                                -0.000000  0.000000
# Pakistani                                            -0.012924  0.000095
# Bangladeshi                                          -0.003784  0.000086
# Asian_Other                                           0.004217  0.000063
# Caribbean                                            -0.000000  0.000045
# Do_not_know                                           0.000871  0.000031
# Chinese                                              -0.007157  0.000070
# Other_ethnicity                                       0.000000  0.000000
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
# Pulse rate                                                 NaN       NaN
#
# algorithm                                          light_gbm            \
# observation                                             mean       std
# feature
# Pulse wave peak to peak time                        0.090410  0.002788
# Pulse wave Arterial Stiffness index                 0.086524  0.002088
# Systolic blood pressure                             0.075894  0.002340
# Diastolic blood pressure                            0.073151  0.001610
# Pulse wave reflection index                         0.066865  0.001470
# Mean carotid IMT (intima-medial thickness) at 1...  0.054863  0.003478
# Mean carotid IMT (intima-medial thickness) at 2...  0.054635  0.001112
# Position of pulse wave notch                        0.052920  0.002097
# Mean carotid IMT (intima-medial thickness) at 2...  0.051092  0.003049
# Mean carotid IMT (intima-medial thickness) at 1...  0.048920  0.001875
# Position of the pulse wave peak                     0.043776  0.002303
# Position of the shoulder on the pulse waveform      0.042176  0.001838
# Minimum carotid IMT (intima-medial thickness) a...  0.030975  0.001292
# Maximum carotid IMT (intima-medial thickness) a...  0.027432  0.001880
# Minimum carotid IMT (intima-medial thickness) a...  0.026060  0.001852
# Maximum carotid IMT (intima-medial thickness) a...  0.025603  0.001440
# Maximum carotid IMT (intima-medial thickness) a...  0.025031  0.001817
# Minimum carotid IMT (intima-medial thickness) a...  0.024917  0.002182
# Maximum carotid IMT (intima-medial thickness) a...  0.024574  0.001532
# Sex                                                 0.023317  0.000779
# Minimum carotid IMT (intima-medial thickness) a...  0.021374  0.000680
# Absence of notch position in the pulse waveform     0.014059  0.000712
# British                                             0.005715  0.000338
# White                                               0.004229  0.000338
# Other                                               0.002057  0.000131
# White_Other                                         0.001257  0.000278
# Irish                                               0.001143  0.000338
# Black                                               0.000800  0.000141
# Indian                                              0.000229  0.000130
# African                                             0.000000  0.000000
# White_and_Black_African                             0.000000  0.000000
# Prefer_not_to_answer                                0.000000  0.000000
# nan                                                 0.000000  0.000000
# Mixed                                               0.000000  0.000000
# White_and_Black_Caribbean                           0.000000  0.000000
# Mixed_Other                                         0.000000  0.000000
# White_and_Asian                                     0.000000  0.000000
# Black_Other                                         0.000000  0.000000
# Asian                                               0.000000  0.000000
# Pakistani                                           0.000000  0.000000
# Bangladeshi                                         0.000000  0.000000
# Asian_Other                                         0.000000  0.000000
# Caribbean                                           0.000000  0.000000
# Do_not_know                                         0.000000  0.000000
# Chinese                                             0.000000  0.000000
# Other_ethnicity                                     0.000000  0.000000
# Pulse rate                                               NaN       NaN
# Pulse rate                                               NaN       NaN
# Pulse rate                                               NaN       NaN
# Pulse rate                                               NaN       NaN
#
# algorithm                                          neural_network
# observation                                                  mean       std
# feature
# Pulse wave peak to peak time                             0.203242  0.016791
# Pulse wave Arterial Stiffness index                      0.135501  0.015240
# Systolic blood pressure                                  0.114500  0.002959
# Diastolic blood pressure                                 0.095013  0.003808
# Pulse wave reflection index                              0.017171  0.000909
# Mean carotid IMT (intima-medial thickness) at 1...       0.011416  0.001513
# Mean carotid IMT (intima-medial thickness) at 2...       0.004128  0.000693
# Position of pulse wave notch                             0.004210  0.000822
# Mean carotid IMT (intima-medial thickness) at 2...       0.010473  0.001131
# Mean carotid IMT (intima-medial thickness) at 1...       0.023151  0.001933
# Position of the pulse wave peak                          0.018413  0.001076
# Position of the shoulder on the pulse waveform           0.006179  0.000684
# Minimum carotid IMT (intima-medial thickness) a...       0.001209  0.000342
# Maximum carotid IMT (intima-medial thickness) a...       0.001052  0.000334
# Minimum carotid IMT (intima-medial thickness) a...       0.000698  0.000216
# Maximum carotid IMT (intima-medial thickness) a...       0.001846  0.000426
# Maximum carotid IMT (intima-medial thickness) a...       0.001953  0.000550
# Minimum carotid IMT (intima-medial thickness) a...       0.001458  0.000151
# Maximum carotid IMT (intima-medial thickness) a...       0.001300  0.000270
# Sex                                                      0.025089  0.001446
# Minimum carotid IMT (intima-medial thickness) a...       0.000615  0.000371
# Absence of notch position in the pulse waveform          0.007391  0.000631
# British                                                  0.045648  0.010694
# White                                                    0.145364  0.035581
# Other                                                    0.013804  0.004583
# White_Other                                              0.019985  0.004531
# Irish                                                    0.008854  0.003523
# Black                                                    0.012076  0.003336
# Indian                                                   0.007479  0.002611
# African                                                  0.004648  0.001612
# White_and_Black_African                                  0.001485  0.001706
# Prefer_not_to_answer                                     0.006521  0.003007
# nan                                                      0.001501  0.001622
# Mixed                                                    0.003455  0.000685
# White_and_Black_Caribbean                                0.000631  0.000410
# Mixed_Other                                              0.000935  0.000221
# White_and_Asian                                          0.000766  0.000414
# Black_Other                                              0.000174  0.000848
# Asian                                                    0.015838  0.005863
# Pakistani                                                0.001237  0.000208
# Bangladeshi                                              0.000738  0.001089
# Asian_Other                                              0.001330  0.000695
# Caribbean                                                0.005198  0.001455
# Do_not_know                                              0.001082  0.003981
# Chinese                                                  0.004806  0.002174
# Other_ethnicity                                          0.010441  0.003079
# Pulse rate                                                    NaN       NaN
# Pulse rate                                                    NaN       NaN
# Pulse rate                                                    NaN       NaN
# Pulse rate                                                    NaN       NaN
