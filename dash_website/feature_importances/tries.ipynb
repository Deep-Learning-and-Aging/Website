# %%
import numpy as np 
channel = 1
time_series = np.load("../../all_data/try.npy")[channel]

# %%
import plotly.graph_objs as go

scatter = go.Scatter(
            y=time_series[0],
            mode="markers",
            marker={"size":5,
                "color":time_series[1],
                "showscale":True,
            },
        )

fig = go.Figure(scatter)
fig.show()
